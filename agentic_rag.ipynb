# %%
import getpass
import os


def _set_env(key: str):
    if key not in os.environ:
        os.environ[key] = getpass.getpass(f"{key}:")


_set_env("OPENAI_API_KEY")

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=100, chunk_overlap=50
)
doc_splits = text_splitter.split_documents(docs_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       3 docs_list = [item for sublist in docs for item in sublist]
#       5 text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
#       6     chunk_size=100, chunk_overlap=50
#       7 )
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\langchain_text_splitters\__init__.py:38
#      36 from langchain_text_splitters.nltk import NLTKTextSplitter
#      37 from langchain_text_splitters.python import PythonCodeTextSplitter
# ---> 38 from langchain_text_splitters.sentence_transformers import (
#      39     SentenceTransformersTokenTextSplitter,
#      40 )
#      41 from langchain_text_splitters.spacy import SpacyTextSplitter
#      43 __all__ = [
#      44     "CharacterTextSplitter",
#      45     "ElementType",
#    (...)     67     "split_text_on_tokens",
#      68 ]
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\langchain_text_splitters\sentence_transformers.py:10
#       7 from langchain_text_splitters.base import TextSplitter, Tokenizer, split_text_on_tokens
#       9 try:
# ---> 10     from sentence_transformers import SentenceTransformer
#      12     _HAS_SENTENCE_TRANSFORMERS = True
#      13 except ImportError:
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\backend\__init__.py:5
#       3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
# ----> 5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#       6 from .utils import (
#       7     _save_pretrained_wrapper,
#       8     backend_should_export,
#       9     backend_warn_to_save,
#      10     save_or_push_to_hub_model,
#      11 )
#      13 __all__ = [
#      14     "load_onnx_model",
#      15     "load_openvino_model",
#    (...)     22     "save_or_push_to_hub_model",
#      23 ]
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\backend\quantize.py:7
#       4 from typing import TYPE_CHECKING, Literal
#       6 from sentence_transformers.backend.utils import save_or_push_to_hub_model
# ----> 7 from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#       9 logger = logging.getLogger(__name__)
#      11 if TYPE_CHECKING:
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\util\__init__.py:15
#      13 from .hard_negatives import mine_hard_negatives
#      14 from .misc import append_to_last_row, disable_datasets_caching, disable_logging, fullname, import_from_string
# ---> 15 from .retrieval import (
#      16     community_detection,
#      17     information_retrieval,
#      18     paraphrase_mining,
#      19     paraphrase_mining_embeddings,
#      20     semantic_search,
#      21 )
#      22 from .similarity import (
#      23     cos_sim,
#      24     dot_score,
#    (...)     32     pytorch_cos_sim,
#      33 )
#      34 from .tensor import (
#      35     _convert_to_batch,
#      36     _convert_to_batch_tensor,
#    (...)     43     truncate_embeddings,
#      44 )
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\util\retrieval.py:13
#      10 from torch import Tensor
#      11 from tqdm.autonotebook import tqdm
# ---> 13 from .similarity import cos_sim
#      14 from .tensor import normalize_embeddings
#      16 logger = logging.getLogger(__name__)
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sentence_transformers\util\similarity.py:5
#       3 import numpy as np
#       4 import torch
# ----> 5 from sklearn.metrics import pairwise_distances
#       6 from torch import Tensor
#       7 from transformers.utils import logging
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)    114     "compose",
#     115 ]
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\base.py:20
#      18 from .exceptions import InconsistentVersionWarning
#      19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#      22 from .utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from ..externals import array_api_extra as xpx
#      19 from ..externals.array_api_compat import numpy as np_compat
# ---> 20 from .fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\sklearn\utils\fixes.py:20
#      17 from scipy import optimize
#      19 try:
# ---> 20     import pandas as pd
#      21 except ImportError:
#      22     pd = None
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\pandas\__init__.py:151
#     133 from pandas.core.reshape.api import (
#     134     concat,
#     135     lreshape,
#    (...)    147     qcut,
#     148 )
#     150 from pandas import api, arrays, errors, io, plotting, tseries
# --> 151 from pandas import testing
#     152 from pandas.util._print_versions import show_versions
#     154 from pandas.io.api import (
#     155     # excel
#     156     ExcelFile,
#    (...)    184     read_spss,
#     185 )
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\pandas\testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File f:\LLM Engineering\projects\llm_engineering\.venv\Lib\site-packages\pandas\_testing\__init__.py:405
#     400     import pytest
#     402     return pytest.raises(expected_exception, match=None)
# --> 405 cython_table = pd.core.common._cython_table.items()
#     408 def get_cython_table_params(ndframe, func_names_and_expected):
#     409     """
#     410     Combine frame, functions from com._cython_table
#     411     keys and expected result.
#    (...)    423         List of three items (DataFrame, function, expected result)
#     424     """
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)
